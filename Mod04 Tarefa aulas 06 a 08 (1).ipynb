# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
data_json = r.json()
print(data_json['items'])
# Out:
# [{'id_pleito': 6363, 'tipo_interessado': 'Município', 'interessado': 'Rio Claro', 'cod_ibge': 3304409, 'uf': 'RJ', 'num_pvl': None, 'status': 'Regularizado', 'num_processo': '17944.000328/2008-34', 'data_protocolo': '2011-06-01T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Regularização de Dívida - Energia Elétrica', 'tipo_credor': 'Empresa Não Estatal', 'credor': 'Light - Serviços de Eletricidade S/A', 'moeda': 'Real', 'valor': 6733230.99, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '22/07/2011'}, {'id_pleito': 7907, 'tipo_interessado': 'Município', 'interessado': 'Mesquita', 'cod_ibge': 3302858, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000675/2010-81', 'data_protocolo': '2010-09-06T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PNAFM', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 5106563, 'pvl_assoc_divid
# ...

# %%
df = pd.DataFrame(data_json['items'])
df
# Out:
#      id_pleito tipo_interessado         interessado  cod_ibge  uf  \
# 0         6363        Município           Rio Claro   3304409  RJ
# 1         7907        Município            Mesquita   3302858  RJ
# 2         7216        Município  São João de Meriti   3305109  RJ
# 3        65407        Município            Itaboraí   3301900  RJ
# 4         5290        Município   Casimiro de Abreu   3301306  RJ
# ..         ...              ...                 ...       ...  ..
# 255      63612        Município             Resende   3304201  RJ
# 256      28822        Município             Resende   3304201  RJ
# 257      56075        Município             Resende   3304201  RJ
# 258      40868        Município           Varre-Sai   3306156  RJ
# 259      33609        Município           Vassouras   3306206  RJ
#
#                   num_pvl              status          num_processo  \
# 0                    None        Regularizado  17944.000328/2008-34
# ...

# %%
# 2) Seu código aqui
df['status'].value_counts()
# Out:
# status
# Deferido                                                 106
# Arquivado                                                 53
# Regularizado                                              26
# Arquivado por decurso de prazo                            24
# Deferido (PVL-IF)                                         24
# Encaminhado à PGFN com manifestação técnica favorável     14
# Arquivado a pedido                                         8
# Em retificação pelo interessado                            2
# Arquivado a pedido (PVL-IF)                                1
# Arquivado pela STN                                         1
# Em retificação pelo credor                                 1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df.dtypes
# Out:
# id_pleito                  int64
# tipo_interessado          object
# interessado               object
# cod_ibge                   int64
# uf                        object
# num_pvl                   object
# status                    object
# num_processo              object
# data_protocolo            object
# tipo_operacao             object
# finalidade                object
# tipo_credor               object
# credor                    object
# moeda                     object
# valor                    float64
# pvl_assoc_divida           int64
# pvl_contradado_credor      int64
# data_status               object
# dtype: object

# %%
ano = df.data_status.squeeze()
ano_separado = ano.str.slice(start=6)
ano_separado
# Out:
# 0      2011
# 1      2010
# 2      2012
# 3      2023
# 4      2014
#        ...
# 255    2023
# 256    2018
# 257    2022
# 258    2020
# 259    2019
# Name: data_status, Length: 260, dtype: object

# %%
ano_freq = ano_separado.value_counts()
ano_freq
# Out:
# data_status
# 2008    37
# 2007    29
# 2023    28
# 2014    20
# 2010    19
# 2019    16
# 2013    15
# 2020    15
# 2012    13
# 2022    11
# 2011    10
# 2009     9
# 2015     8
# 2017     5
# 2021     5
# 2018     4
# 2002     4
# 2006     4
# 2016     4
# 2024     2
# 2003     1
# 2004     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código
def consultar_dados (uf, tipo_interessado):
    if tipo_interessado == 'Estado' :
        url2 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=xxx&tipo_interessado=Estado'
        novo_url = url2.replace('xxx', uf)
        req = requests.get(novo_url)
        data_json2 = req.json()
        df2 = pd.DataFrame(data_json2['items'])
    else :
        url2 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=xxx&tipo_interessado=Munic%C3%ADpio'
        novo_url = url2.replace('xxx', uf)
        req = requests.get(novo_url)
        data_json2 = req.json()
        df2 = pd.DataFrame(data_json2['items'])
    return df2

# %%
# 2) Seu código aqui
consulta_mg = consultar_dados ('MG', 'Estado')
consulta_mg['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Arquivado por decurso de prazo                            1
# Indeferido                                                1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
consulta_ba = consultar_dados ('BA', 'Município')
consulta_ba['interessado'].value_counts()
# Out:
# interessado
# Salvador                  19
# Camaçari                  19
# Luís Eduardo Magalhães    18
# Vitória da Conquista      15
# Amargosa                  15
#                           ..
# Coração de Maria           1
# Jandaíra                   1
# Várzea Nova                1
# Tanque Novo                1
# Jucuruçu                   1
# Name: count, Length: 298, dtype: int64

# %%
consulta_ba.to_csv(index= False, sep=';')
# Out:
# "id_pleito;tipo_interessado;interessado;cod_ibge;uf;num_pvl;status;num_processo;data_protocolo;tipo_operacao;finalidade;tipo_credor;credor;moeda;valor;pvl_assoc_divida;pvl_contradado_credor;data_status\r\n6710;Município;Cocos;2908101;BA;;Deferido;17944.000413/2011-06;2011-04-26T03:00:00Z;Operação contratual interna;Aquisição de máquinas, equipamentos e veículos;Instituição Financeira Nacional;Agência de Fomento do Estado da Bahia S/A;Real;650000.0;1;0;09/05/2011\r\n7366;Município;Coribe;2909109;BA;;Deferido;17944.000555/2013-27;2013-07-08T03:00:00Z;Operação contratual interna;Aquisição de máquinas, equipamentos e veículos;Instituição Financeira Nacional;Agência de Fomento do Estado da Bahia S/A;Real;65000.0;0;0;25/07/2013\r\n7395;Município;Wagner;2933406;BA;;Deferido;17944.000565/2008-03;2008-04-04T03:00:00Z;Operação contratual interna;Caminho da Escola 2;Instituição Financeira Nacional;Banco do Brasil S/A;Real;299450.0;0;0;16/05/2008\r\n6562;Município;Mucugê;2921906;BA;;Arquivado po
# ...
