# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos_mat'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos_por'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_geo'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_ing'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_his'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos_fis'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos_qui'])

tabela_geral = pd.df = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1)
tabela_geral
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 0                6               7               7               3
# 1               19              10               0               0
# 2               14              16               0               5
# 3               10               7               3               4
# 4                7               2               2               7
# ..             ...             ...             ...             ...
# 95               6               4               7               1
# 96               8               1               4               6
# 97              23               5               0               2
# 98               0              10               3               1
# 99              11              15               0               1
#
#     Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui
# 0                1               8               3
# 1                0              11               8
# ...

# %%
# 1) Seu código aqui

porc_acertos_mat = df_mat/24

porc_acertos_por = df_por/18

porc_acertos_ing = df_ing/8

porc_acertos_his = df_his/8

porc_acertos_fis = df_fis/12

porc_acertos_qui = df_qui/12

# %%
# 2) Seu código aqui
tabela_geral ["acertos_totais"] = (tabela_geral['Qt_acertos_fis'] + tabela_geral['Qt_acertos_geo'] + 
                                   tabela_geral['Qt_acertos_his'] + tabela_geral['Qt_acertos_ing'] + 
                                   tabela_geral['Qt_acertos_mat'] + tabela_geral['Qt_acertos_por'] +
                                   tabela_geral['Qt_acertos_qui'] )
tabela_geral
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 0                6               7               7               3
# 1               19              10               0               0
# 2               14              16               0               5
# 3               10               7               3               4
# 4                7               2               2               7
# ..             ...             ...             ...             ...
# 95               6               4               7               1
# 96               8               1               4               6
# 97              23               5               0               2
# 98               0              10               3               1
# 99              11              15               0               1
#
#     Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui  acertos_totais
# 0                1               8               3              35
# ...

# %%
# 3) Seu código aqui
porc_total_acertos= tabela_geral['acertos_totais']/90
porc_total_acertos
# Out:
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
#         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
# Name: acertos_totais, Length: 100, dtype: float64

# %%
# 4) Seu código aqui
alunos_acertos_maior_45 = tabela_geral.loc[tabela_geral['acertos_totais'] >45, 'acertos_totais']
alunos_acertos_maior_45.count()
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
#1)
# seu código aqui 
df_desq = tabela_geral[(['Qt_acertos_mat'] == 0) | 
                      (tabela_geral['Qt_acertos_fis'] == 0) | 
                      (tabela_geral['Qt_acertos_qui'] == 0)]

df_desq
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 3               10               7               3               4
# 6                6               0               7               7
# 10              10               8               3               2
# 12              20               8               3               7
# 14               7              11               1               7
# 20              23              11               6               5
# 26              11              14               6               2
# 27              21              13               1               5
# 33              14               8               0               5
# 35              11              14               6               3
# 49               8               1               1               0
# 56               7               6               7               5
# 65               1               8               2               4
# ...

# %%
#2)
df_desq.count()
# Out:
# Qt_acertos_mat    20
# Qt_acertos_por    20
# Qt_acertos_geo    20
# Qt_acertos_ing    20
# Qt_acertos_his    20
# Qt_acertos_fis    20
# Qt_acertos_qui    20
# acertos_totais    20
# dtype: int64

# %%
#3) Média em História
desq_med_his = df_desq["Qt_acertos_his"].mean()
desq_med_his
# Out:
# 3.65

# %%
#3) Média em Geografia
desq_med_geo = df_desq["Qt_acertos_geo"].mean()
desq_med_geo
# Out:
# 3.1

# %%
#4
alunos_passaram = tabela_geral.drop(index=df_desq.index) 
alunos_passaram
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 0                6               7               7               3
# 1               19              10               0               0
# 2               14              16               0               5
# 4                7               2               2               7
# 5               20               2               5               3
# ..             ...             ...             ...             ...
# 95               6               4               7               1
# 96               8               1               4               6
# 97              23               5               0               2
# 98               0              10               3               1
# 99              11              15               0               1
#
#     Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui  acertos_totais
# 0                1               8               3              35
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-97829158-cc41-4c75-aec4-752344e6e938.c000.csv'

# %%
df = pd.read_csv(arquivo, sep=';')
df.head(8)
# Out:
#                                  document_id  \
# 0  a7b2e803-75ae-4c59-baa7-421d87f9a707-i0b0
# 1  5ec41855-c5b8-44de-88d0-a474814e9df0-i0b0
# 2  c5b89122-8166-4f7e-9ef3-1a98c8e65d52-i0b0
# 3  5ef90995-413a-44df-bfb2-64dec20fc20f-i0b0
# 4  7177c695-3e14-42fd-8a7c-ef76ebe92360-i0b0
# 5  5ef9c979-cd95-4a7e-b4ca-40eddba05af3-i0b0
# 6  74629aec-ea92-40cd-868e-23620e6cd055-i0b0
# 7  5f075166-5ef1-42be-bee5-f1d1d72f9d56-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  3e35925a3512d7901cd2974eb662e25b6130ee42e72317...              30
# 1  ac91ba1d57f1ec0a8c88e393ed7e162914cecaa47d8624...              38
# 2  578eff022445b36a42ef61a011ec5517523a563c5321a7...              20
# 3  6991fbfb4e56ef4193b09f7a6203604356b3c3b739101e...              30
# 4  b1ead8d542ffb8e8f387426cb6e134d39979759c1ae190...              63
# 5  488a76d5c8ffe25c04ed138416441e0767c2cbe607d9be...              34
# 6  23545e868e3c4555ca5b0452613d44275102e44d432e27...              15
# ...

# %%
# 1) Sua solução aqui
df.vacina_nome.nunique()
# Out:
# 12

# %%
# 2)
df.paciente_id.nunique()
# Out:
# 308842

# %%
# 3) 
df_1a_dose= df.loc[df['vacina_descricao_dose']=='1ª Dose']
df_1a_dose.paciente_id.nunique()
# Out:
# 141243

# %%
# 4)
df_menor_18 = df.loc[df['paciente_idade']<18]
df_menor_18.paciente_id.nunique()
# Out:
# 63276

# %%
df['estabelecimento_razaoSocial']
# Out:
# 0                   SECRETARIA MUNICIPAL DE SAUDE
# 1                   PREFEITURA MUNICIPAL DE SAUDE
# 2              PREFEITURA MUNICIPAL DE RIO BRANCO
# 3         PREFEITURA MUNICIIPAL DE SENA MADUREIRA
# 4              PREFEITURA MUNICIPAL DE RIO BRANCO
#                            ...
# 375519     PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 375520         PREFEITURA MUNICIPAL DE RIO BRANCO
# 375521     PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 375522    PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 375523         PREFEITURA MUNICIPAL DE RIO BRANCO
# Name: estabelecimento_razaoSocial, Length: 375524, dtype: object

# %%
# 5)
df.estabelecimento_razaoSocial.nunique()
# Out:
# 55

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_menor_18 = df[df["paciente_idade"]<18].copy()
df_menor_18
# Out:
#                                       document_id  \
# 6       74629aec-ea92-40cd-868e-23620e6cd055-i0b0
# 9       5f2afecd-7550-4f5c-9afb-86043a6f06aa-i0b0
# 14      96b08b97-3224-4c9c-aec7-9c03fbddb3cc-i0b0
# 18      e5c2279b-611f-43d3-90f7-464bf7b922ed-i0b0
# 24      8d55063b-1d12-4a97-8351-c1263f110e81-i0b0
# ...                                           ...
# 375504  cf5b652c-f907-41d1-85db-26594905599f-i0b0
# 375505  cfc17e79-db4f-46e6-9984-3e9245b77d35-i0b0
# 375518  d0dbece5-33d7-4e29-982c-aa26bea10ac1-i0b0
# 375521  d1512879-1dcd-4a80-9dca-21597ac68b9b-i0b0
# 375522  d15e007a-f7d9-43f2-bb5c-94a0986f4cf7-i0b0
#
#                                               paciente_id  paciente_idade  \
# 6       23545e868e3c4555ca5b0452613d44275102e44d432e27...              15
# 9       3c801e3d6595fb034082a1477d767e3e8a6a5a8830a964...              12
# 14      3e955dff89eac98b6f8c9bf109305e0bea141ca33acacd...              15
# ...

# %%
# 2)
df_menor_18.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)
df_menor_18.vacina_categoria_nome.value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                      42455
# Povos Indígenas                                    3829
# Outros                                             3697
# Povos e Comunidades Tradicionais                    681
# Trabalhadores de Saúde                              238
# Comorbidades                                         55
# População Privada de Liberdade                       51
# Gestantes                                            34
# Pessoas com Deficiência                              10
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Trabalhadores da Educação                             1
# Name: count, dtype: int64

# %%
# 4)
df_menor_18_lista_estab = df_menor_18.loc[:,'estabelecimento_valor':'estabelecimento_uf']
df_menor_18_lista_estab
# Out:
#         estabelecimento_valor                  estabelecimento_razaoSocial  \
# 6                     6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 9                     2001314       PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 14                    2000156             PREFEITURA MUNICIPAL DE TARAUACA
# 18                    6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 24                    2001772  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
# ...                       ...                                          ...
# 375504                6159087      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 375505                2002132            PREFEITURA MUN DE MAL THAUMATURGO
# 375518                6159087      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 375521                2002566       PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 375522                2000326      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 5)
df_menor_18_lista_estab = df_menor_18_lista_estab.drop_duplicates()
df_menor_18_lista_estab.shape
# Out:
# (178, 6)
